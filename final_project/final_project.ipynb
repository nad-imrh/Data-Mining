# %%
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# %% [markdown]
# # **NADILA IMAARAH 3323600015 D4 SAINS DATA TERAPAN A**

# %% [markdown]
# # 1. Load dataset dan tampilkan

# %%
dataset = pd.read_csv('transaction.csv')
print("Dataset:")
dataset.head()
# Out:
# Dataset:
#    InvoiceNo  StockCode  Qty      InvoiceDate  CustomerID  Country
# 0     537626      22725  830  12/7/2010 14:57       12347  Iceland
# 1     537626      22729  948  12/7/2010 14:57       12347  Iceland
# 2     537626      22195  695  12/7/2010 14:57       12347  Iceland
# 3     542237      22725  636  1/26/2011 14:30       12347  Iceland
# 4     542237      22729  536  1/26/2011 14:30       12347  Iceland

# %% [markdown]
# # 2. ambillah data pada dataset untuk fitur InvoiceNo, Country, month, year (“2011”)

# %%
# 2. Konversi InvoiceDate ke datetime dan ambil fitur InvoiceNo, Country, month, year 
dataset['InvoiceDate'] = pd.to_datetime(dataset['InvoiceDate'])
data = dataset[['InvoiceNo', 'Country', 'InvoiceDate']].copy()
data['month'] = data['InvoiceDate'].dt.month
data['year'] = data['InvoiceDate'].dt.year

# Filter hanya tahun 2011
data = data[data['year'] == 2011]
print("\nData setelah filter tahun 2011 dan ekstraksi fitur:")
data.head()
# Out:
# Data setelah filter tahun 2011 dan ekstraksi fitur:
#    InvoiceNo  Country         InvoiceDate  month  year
# 3     542237  Iceland 2011-01-26 14:30:00      1  2011
# 4     542237  Iceland 2011-01-26 14:30:00      1  2011
# 5     542237  Iceland 2011-01-26 14:30:00      1  2011
# 6     542237  Iceland 2011-01-26 14:30:00      1  2011
# 7     542237  Iceland 2011-01-26 14:30:00      1  2011

# %% [markdown]
# # Tahap NO 3-8

# %%
transaksi_tinggi = []

for i in range(1, 13):
    print(f"\n--- Bulan ke-{i} ---")
    
    # 3. Data bulan ke-i
    data_bulan = data[data['month'] == i]
    print(f"Data bulan ke-{i} (sample):")
    print(data_bulan.head(1))
    
    # 4. Hitung transaksi per negara (InvoiceNo unik per Country)
    
    transaksi = data_bulan.drop_duplicates(subset=['InvoiceNo', 'Country'])
    transaksi_per_country = transaksi.groupby('Country')['InvoiceNo'].nunique().reset_index()
    transaksi_per_country.columns = ['Country', 'TransactionCount']
    print("Transaksi per negara:")
    print(transaksi_per_country)
    
    # Jika data negara kurang dari 3, append 0 dan lanjut ke bulan berikutnya
    if len(transaksi_per_country) < 3:
        print(f"Data kurang dari 3 negara, lewati clustering bulan {i}.")
        transaksi_tinggi.append(0)
        continue
    
    # 5. Clustering dengan AgglomerativeClustering (Average Linkage, k=3)
    clustering = AgglomerativeClustering(n_clusters=3, linkage='average')
    clustering.fit(transaksi_per_country[['TransactionCount']])
    transaksi_per_country['Cluster'] = clustering.labels_
    print("Hasil clustering:")
    print(transaksi_per_country)
    
    # 6. Tentukan centroid (rata-rata transaksi tiap cluster)
    centroid = transaksi_per_country.groupby('Cluster')['TransactionCount'].mean().reset_index()
    print("Centroid per cluster:")
    print(centroid)
    
    # 7. Urutkan centroid ascending berdasarkan TransactionCount
    sorted_centroid = centroid.sort_values(by='TransactionCount').reset_index(drop=True)
    print("Centroid setelah diurutkan (ascending):")
    print(sorted_centroid)
    
    # 8. Ambil nilai tertinggi (indeks terakhir)
    nilai_tertinggi = sorted_centroid.loc[len(sorted_centroid) - 1, 'TransactionCount']
    transaksi_tinggi.append(nilai_tertinggi)
    print(f"Nilai transaksi tertinggi bulan {i}: {nilai_tertinggi}")
# Out:
# --- Bulan ke-1 ---
# Data bulan ke-1 (sample):
#    InvoiceNo  Country         InvoiceDate  month  year
# 3     542237  Iceland 2011-01-26 14:30:00      1  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0         Australia                 5
# 1           Belgium                 3
# 2   Channel Islands                 1
# 3            Cyprus                 1
# 4              EIRE                 7
# 5           Finland                 1
# 6            France                26
# 7           Germany                28
# 8            Greece                 1
# 9           Iceland                 1
# 10            Italy                 3
# 11          Lebanon                 1
# 12      Netherlands                 4
# 13           Poland                 1
# 14         Portugal                 4
# 15        Singapore                 1
# 16            Spain                 7
# 17           Sweden                 2
# 18      Switzerland                 3
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0         Australia                 5        0
# 1           Belgium                 3        0
# 2   Channel Islands                 1        0
# 3            Cyprus                 1        0
# 4              EIRE                 7        2
# 5           Finland                 1        0
# 6            France                26        1
# 7           Germany                28        1
# 8            Greece                 1        0
# 9           Iceland                 1        0
# 10            Italy                 3        0
# 11          Lebanon                 1        0
# 12      Netherlands                 4        0
# 13           Poland                 1        0
# 14         Portugal                 4        0
# 15        Singapore                 1        0
# 16            Spain                 7        2
# 17           Sweden                 2        0
# 18      Switzerland                 3        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          2.133333
# 1        1         27.000000
# 2        2          7.000000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0          2.133333
# 1        2          7.000000
# 2        1         27.000000
# Nilai transaksi tertinggi bulan 1: 27.0
#
# --- Bulan ke-2 ---
# Data bulan ke-2 (sample):
#     InvoiceNo Country         InvoiceDate  month  year
# 57     543037  Norway 2011-02-02 16:01:00      2  2011
# Transaksi per negara:
#                  Country  TransactionCount
# 0              Australia                 4
# 1                Austria                 1
# 2                Belgium                 4
# 3        Channel Islands                 1
# 4                 Cyprus                 4
# 5         Czech Republic                 1
# 6                Denmark                 1
# 7                   EIRE                 9
# 8                Finland                 1
# 9                 France                20
# 10               Germany                18
# 11                Israel                 1
# 12                 Italy                 1
# 13                 Japan                 2
# 14           Netherlands                 5
# 15                Norway                 2
# 16                Poland                 2
# 17              Portugal                 2
# 18          Saudi Arabia                 1
# 19                 Spain                 4
# 20                Sweden                 1
# 21           Switzerland                 4
# 22  United Arab Emirates                 1
# Hasil clustering:
#                  Country  TransactionCount  Cluster
# 0              Australia                 4        0
# 1                Austria                 1        0
# 2                Belgium                 4        0
# 3        Channel Islands                 1        0
# 4                 Cyprus                 4        0
# 5         Czech Republic                 1        0
# 6                Denmark                 1        0
# 7                   EIRE                 9        2
# 8                Finland                 1        0
# 9                 France                20        1
# 10               Germany                18        1
# 11                Israel                 1        0
# 12                 Italy                 1        0
# 13                 Japan                 2        0
# 14           Netherlands                 5        0
# 15                Norway                 2        0
# 16                Poland                 2        0
# 17              Portugal                 2        0
# 18          Saudi Arabia                 1        0
# 19                 Spain                 4        0
# 20                Sweden                 1        0
# 21           Switzerland                 4        0
# 22  United Arab Emirates                 1        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0              2.15
# 1        1             19.00
# 2        2              9.00
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0              2.15
# 1        2              9.00
# 2        1             19.00
# Nilai transaksi tertinggi bulan 2: 19.0
#
# --- Bulan ke-3 ---
# Data bulan ke-3 (sample):
#     InvoiceNo Country         InvoiceDate  month  year
# 61     546869  Norway 2011-03-17 16:00:00      3  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0         Australia                 3
# 1           Austria                 1
# 2           Belgium                 8
# 3   Channel Islands                 3
# 4            Cyprus                 1
# 5           Denmark                 1
# 6              EIRE                17
# 7           Finland                 3
# 8            France                23
# 9           Germany                26
# 10           Greece                 1
# 11            Italy                 3
# 12            Japan                 2
# 13      Netherlands                 8
# 14           Norway                 2
# 15           Poland                 1
# 16         Portugal                 4
# 17            Spain                 7
# 18           Sweden                 2
# 19      Switzerland                 2
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0         Australia                 3        0
# 1           Austria                 1        0
# 2           Belgium                 8        0
# 3   Channel Islands                 3        0
# 4            Cyprus                 1        0
# 5           Denmark                 1        0
# 6              EIRE                17        2
# 7           Finland                 3        0
# 8            France                23        1
# 9           Germany                26        1
# 10           Greece                 1        0
# 11            Italy                 3        0
# 12            Japan                 2        0
# 13      Netherlands                 8        0
# 14           Norway                 2        0
# 15           Poland                 1        0
# 16         Portugal                 4        0
# 17            Spain                 7        0
# 18           Sweden                 2        0
# 19      Switzerland                 2        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          3.058824
# 1        1         24.500000
# 2        2         17.000000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0          3.058824
# 1        2         17.000000
# 2        1         24.500000
# Nilai transaksi tertinggi bulan 3: 24.5
#
# --- Bulan ke-4 ---
# Data bulan ke-4 (sample):
#    InvoiceNo  Country         InvoiceDate  month  year
# 8     549222  Iceland 2011-04-07 10:43:00      4  2011
# Transaksi per negara:
#                Country  TransactionCount
# 0            Australia                 1
# 1              Austria                 1
# 2              Belgium                 7
# 3               Brazil                 1
# 4      Channel Islands                 1
# 5              Denmark                 1
# 6                 EIRE                11
# 7   European Community                 1
# 8              Finland                 3
# 9               France                11
# 10             Germany                21
# 11              Greece                 1
# 12             Iceland                 1
# 13               Italy                 2
# 14               Japan                 2
# 15         Netherlands                 3
# 16              Poland                 1
# 17            Portugal                 2
# 18           Singapore                 1
# 19               Spain                 2
# 20              Sweden                 1
# 21         Switzerland                 2
# 22                 USA                 1
# 23         Unspecified                 1
# Hasil clustering:
#                Country  TransactionCount  Cluster
# 0            Australia                 1        2
# 1              Austria                 1        2
# 2              Belgium                 7        0
# 3               Brazil                 1        2
# 4      Channel Islands                 1        2
# 5              Denmark                 1        2
# 6                 EIRE                11        0
# 7   European Community                 1        2
# 8              Finland                 3        2
# 9               France                11        0
# 10             Germany                21        1
# 11              Greece                 1        2
# 12             Iceland                 1        2
# 13               Italy                 2        2
# 14               Japan                 2        2
# 15         Netherlands                 3        2
# 16              Poland                 1        2
# 17            Portugal                 2        2
# 18           Singapore                 1        2
# 19               Spain                 2        2
# 20              Sweden                 1        2
# 21         Switzerland                 2        2
# 22                 USA                 1        2
# 23         Unspecified                 1        2
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          9.666667
# 1        1         21.000000
# 2        2          1.450000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        2          1.450000
# 1        0          9.666667
# 2        1         21.000000
# Nilai transaksi tertinggi bulan 4: 21.0
#
# --- Bulan ke-5 ---
# Data bulan ke-5 (sample):
#     InvoiceNo  Country         InvoiceDate  month  year
# 98     552449  Bahrain 2011-05-09 13:49:00      5  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0         Australia                 4
# 1           Austria                 1
# 2           Bahrain                 1
# 3           Belgium                 7
# 4   Channel Islands                 1
# 5           Denmark                 1
# 6              EIRE                16
# 7            France                34
# 8           Germany                33
# 9             Italy                 1
# 10            Japan                 1
# 11      Netherlands                 8
# 12           Poland                 3
# 13         Portugal                 1
# 14            Spain                 3
# 15           Sweden                 1
# 16      Switzerland                 3
# 17      Unspecified                 1
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0         Australia                 4        0
# 1           Austria                 1        0
# 2           Bahrain                 1        0
# 3           Belgium                 7        0
# 4   Channel Islands                 1        0
# 5           Denmark                 1        0
# 6              EIRE                16        2
# 7            France                34        1
# 8           Germany                33        1
# 9             Italy                 1        0
# 10            Japan                 1        0
# 11      Netherlands                 8        0
# 12           Poland                 3        0
# 13         Portugal                 1        0
# 14            Spain                 3        0
# 15           Sweden                 1        0
# 16      Switzerland                 3        0
# 17      Unspecified                 1        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          2.466667
# 1        1         33.500000
# 2        2         16.000000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0          2.466667
# 1        2         16.000000
# 2        1         33.500000
# Nilai transaksi tertinggi bulan 5: 33.5
#
# --- Bulan ke-6 ---
# Data bulan ke-6 (sample):
#     InvoiceNo  Country         InvoiceDate  month  year
# 14     556201  Iceland 2011-06-09 13:01:00      6  2011
# Transaksi per negara:
#                Country  TransactionCount
# 0            Australia                 4
# 1              Belgium                 9
# 2               Canada                 1
# 3      Channel Islands                 1
# 4               Cyprus                 2
# 5              Denmark                 3
# 6                 EIRE                20
# 7   European Community                 1
# 8              Finland                 1
# 9               France                28
# 10             Germany                20
# 11             Iceland                 1
# 12               Italy                 1
# 13               Japan                 1
# 14               Malta                 1
# 15         Netherlands                10
# 16              Norway                 3
# 17              Poland                 1
# 18            Portugal                 2
# 19               Spain                 7
# 20              Sweden                 3
# 21         Switzerland                 3
# 22         Unspecified                 1
# Hasil clustering:
#                Country  TransactionCount  Cluster
# 0            Australia                 4        0
# 1              Belgium                 9        0
# 2               Canada                 1        0
# 3      Channel Islands                 1        0
# 4               Cyprus                 2        0
# 5              Denmark                 3        0
# 6                 EIRE                20        1
# 7   European Community                 1        0
# 8              Finland                 1        0
# 9               France                28        2
# 10             Germany                20        1
# 11             Iceland                 1        0
# 12               Italy                 1        0
# 13               Japan                 1        0
# 14               Malta                 1        0
# 15         Netherlands                10        0
# 16              Norway                 3        0
# 17              Poland                 1        0
# 18            Portugal                 2        0
# 19               Spain                 7        0
# 20              Sweden                 3        0
# 21         Switzerland                 3        0
# 22         Unspecified                 1        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0               2.8
# 1        1              20.0
# 2        2              28.0
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0               2.8
# 1        1              20.0
# 2        2              28.0
# Nilai transaksi tertinggi bulan 6: 28.0
#
# --- Bulan ke-7 ---
# Data bulan ke-7 (sample):
#      InvoiceNo  Country         InvoiceDate  month  year
# 130     559707  Austria 2011-07-12 10:04:00      7  2011
# Transaksi per negara:
#                Country  TransactionCount
# 0            Australia                 5
# 1              Austria                 2
# 2              Belgium                 3
# 3               Canada                 1
# 4               Cyprus                 1
# 5              Denmark                 1
# 6                 EIRE                18
# 7   European Community                 1
# 8              Finland                 2
# 9               France                21
# 10             Germany                29
# 11              Greece                 1
# 12              Israel                 1
# 13               Italy                 1
# 14               Japan                 2
# 15         Netherlands                 1
# 16              Norway                 1
# 17              Poland                 2
# 18            Portugal                 3
# 19           Singapore                 1
# 20               Spain                 5
# 21              Sweden                 3
# 22         Switzerland                 5
# 23         Unspecified                 3
# Hasil clustering:
#                Country  TransactionCount  Cluster
# 0            Australia                 5        0
# 1              Austria                 2        0
# 2              Belgium                 3        0
# 3               Canada                 1        0
# 4               Cyprus                 1        0
# 5              Denmark                 1        0
# 6                 EIRE                18        1
# 7   European Community                 1        0
# 8              Finland                 2        0
# 9               France                21        1
# 10             Germany                29        2
# 11              Greece                 1        0
# 12              Israel                 1        0
# 13               Italy                 1        0
# 14               Japan                 2        0
# 15         Netherlands                 1        0
# 16              Norway                 1        0
# 17              Poland                 2        0
# 18            Portugal                 3        0
# 19           Singapore                 1        0
# 20               Spain                 5        0
# 21              Sweden                 3        0
# 22         Switzerland                 5        0
# 23         Unspecified                 3        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          2.142857
# 1        1         19.500000
# 2        2         29.000000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0          2.142857
# 1        1         19.500000
# 2        2         29.000000
# Nilai transaksi tertinggi bulan 7: 29.0
#
# --- Bulan ke-8 ---
# Data bulan ke-8 (sample):
#     InvoiceNo  Country         InvoiceDate  month  year
# 19     562032  Iceland 2011-08-02 08:48:00      8  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0         Australia                 2
# 1           Austria                 2
# 2           Belgium                 8
# 3            Canada                 1
# 4   Channel Islands                 5
# 5            Cyprus                 1
# 6           Denmark                 1
# 7              EIRE                15
# 8           Finland                 3
# 9            France                24
# 10          Germany                29
# 11          Iceland                 1
# 12           Israel                 1
# 13            Italy                 3
# 14            Malta                 1
# 15      Netherlands                 6
# 16           Norway                 2
# 17           Poland                 1
# 18         Portugal                 1
# 19            Spain                 7
# 20           Sweden                 4
# 21      Switzerland                 3
# 22      Unspecified                 2
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0         Australia                 2        1
# 1           Austria                 2        1
# 2           Belgium                 8        1
# 3            Canada                 1        1
# 4   Channel Islands                 5        1
# 5            Cyprus                 1        1
# 6           Denmark                 1        1
# 7              EIRE                15        2
# 8           Finland                 3        1
# 9            France                24        0
# 10          Germany                29        0
# 11          Iceland                 1        1
# 12           Israel                 1        1
# 13            Italy                 3        1
# 14            Malta                 1        1
# 15      Netherlands                 6        1
# 16           Norway                 2        1
# 17           Poland                 1        1
# 18         Portugal                 1        1
# 19            Spain                 7        1
# 20           Sweden                 4        1
# 21      Switzerland                 3        1
# 22      Unspecified                 2        1
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0             26.50
# 1        1              2.75
# 2        2             15.00
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        1              2.75
# 1        2             15.00
# 2        0             26.50
# Nilai transaksi tertinggi bulan 8: 26.5
#
# --- Bulan ke-9 ---
# Data bulan ke-9 (sample):
#     InvoiceNo  Country         InvoiceDate  month  year
# 43     568172  Finland 2011-09-25 13:13:00      9  2011
# Transaksi per negara:
#                  Country  TransactionCount
# 0              Australia                 6
# 1                Belgium                 6
# 2        Channel Islands                 2
# 3                 Cyprus                 1
# 4                Denmark                 3
# 5                   EIRE                28
# 6                Finland                 3
# 7                 France                43
# 8                Germany                33
# 9                  Italy                 1
# 10           Netherlands                 6
# 11                Norway                 6
# 12                Poland                 2
# 13              Portugal                 3
# 14                 Spain                 7
# 15                Sweden                 3
# 16           Switzerland                 4
# 17  United Arab Emirates                 1
# Hasil clustering:
#                  Country  TransactionCount  Cluster
# 0              Australia                 6        1
# 1                Belgium                 6        1
# 2        Channel Islands                 2        1
# 3                 Cyprus                 1        1
# 4                Denmark                 3        1
# 5                   EIRE                28        0
# 6                Finland                 3        1
# 7                 France                43        2
# 8                Germany                33        0
# 9                  Italy                 1        1
# 10           Netherlands                 6        1
# 11                Norway                 6        1
# 12                Poland                 2        1
# 13              Portugal                 3        1
# 14                 Spain                 7        1
# 15                Sweden                 3        1
# 16           Switzerland                 4        1
# 17  United Arab Emirates                 1        1
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0              30.5
# 1        1               3.6
# 2        2              43.0
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        1               3.6
# 1        0              30.5
# 2        2              43.0
# Nilai transaksi tertinggi bulan 9: 43.0
#
# --- Bulan ke-10 ---
# Data bulan ke-10 (sample):
#     InvoiceNo  Country         InvoiceDate  month  year
# 27     573511  Iceland 2011-10-31 12:25:00     10  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0         Australia                 4
# 1           Austria                 1
# 2           Belgium                11
# 3   Channel Islands                 3
# 4            Cyprus                 3
# 5    Czech Republic                 1
# 6           Denmark                 2
# 7              EIRE                27
# 8           Finland                 4
# 9            France                25
# 10          Germany                47
# 11          Iceland                 1
# 12           Israel                 1
# 13            Italy                 6
# 14            Japan                 1
# 15      Netherlands                 9
# 16           Norway                 4
# 17         Portugal                 6
# 18              RSA                 1
# 19        Singapore                 1
# 20            Spain                 7
# 21           Sweden                 2
# 22      Switzerland                 5
# 23              USA                 2
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0         Australia                 4        0
# 1           Austria                 1        0
# 2           Belgium                11        0
# 3   Channel Islands                 3        0
# 4            Cyprus                 3        0
# 5    Czech Republic                 1        0
# 6           Denmark                 2        0
# 7              EIRE                27        1
# 8           Finland                 4        0
# 9            France                25        1
# 10          Germany                47        2
# 11          Iceland                 1        0
# 12           Israel                 1        0
# 13            Italy                 6        0
# 14            Japan                 1        0
# 15      Netherlands                 9        0
# 16           Norway                 4        0
# 17         Portugal                 6        0
# 18              RSA                 1        0
# 19        Singapore                 1        0
# 20            Spain                 7        0
# 21           Sweden                 2        0
# 22      Switzerland                 5        0
# 23              USA                 2        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          3.571429
# 1        1         26.000000
# 2        2         47.000000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0          3.571429
# 1        1         26.000000
# 2        2         47.000000
# Nilai transaksi tertinggi bulan 10: 47.0
#
# --- Bulan ke-11 ---
# Data bulan ke-11 (sample):
#     InvoiceNo Country         InvoiceDate  month  year
# 44     577609   Italy 2011-11-21 09:51:00     11  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0         Australia                 3
# 1           Austria                 2
# 2           Belgium                 9
# 3   Channel Islands                 1
# 4            Cyprus                 1
# 5           Denmark                 2
# 6              EIRE                36
# 7           Finland                 3
# 8            France                58
# 9           Germany                52
# 10            Italy                 7
# 11            Japan                 1
# 12      Netherlands                11
# 13           Norway                 5
# 14           Poland                 2
# 15         Portugal                 6
# 16            Spain                10
# 17           Sweden                 3
# 18      Switzerland                 5
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0         Australia                 3        0
# 1           Austria                 2        0
# 2           Belgium                 9        0
# 3   Channel Islands                 1        0
# 4            Cyprus                 1        0
# 5           Denmark                 2        0
# 6              EIRE                36        2
# 7           Finland                 3        0
# 8            France                58        1
# 9           Germany                52        1
# 10            Italy                 7        0
# 11            Japan                 1        0
# 12      Netherlands                11        0
# 13           Norway                 5        0
# 14           Poland                 2        0
# 15         Portugal                 6        0
# 16            Spain                10        0
# 17           Sweden                 3        0
# 18      Switzerland                 5        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0            4.4375
# 1        1           55.0000
# 2        2           36.0000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0            4.4375
# 1        2           36.0000
# 2        1           55.0000
# Nilai transaksi tertinggi bulan 11: 55.0
#
# --- Bulan ke-12 ---
# Data bulan ke-12 (sample):
#      InvoiceNo  Country         InvoiceDate  month  year
# 131     581232  Austria 2011-12-08 10:26:00     12  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0           Austria                 1
# 1           Belgium                 4
# 2   Channel Islands                 1
# 3           Denmark                 1
# 4              EIRE                 9
# 5           Finland                 1
# 6            France                15
# 7           Germany                16
# 8            Greece                 1
# 9             Italy                 1
# 10      Netherlands                 3
# 11           Norway                 1
# 12         Portugal                 4
# 13            Spain                 2
# 14              USA                 2
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0           Austria                 1        0
# 1           Belgium                 4        0
# 2   Channel Islands                 1        0
# 3           Denmark                 1        0
# 4              EIRE                 9        2
# 5           Finland                 1        0
# 6            France                15        1
# 7           Germany                16        1
# 8            Greece                 1        0
# 9             Italy                 1        0
# 10      Netherlands                 3        0
# 11           Norway                 1        0
# 12         Portugal                 4        0
# 13            Spain                 2        0
# 14              USA                 2        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          1.833333
# 1        1         15.500000
# 2        2          9.000000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0          1.833333
# 1        2          9.000000
# 2        1         15.500000
# Nilai transaksi tertinggi bulan 12: 15.5

# %% [markdown]
# # 9. Visualisasikan pergerakan nilai transaksi_tinggi dimana sumbu x=month(1-12) dan sumbu y=transaksi_tinggi (centroid ini yang di visualisasikan tetringgi pada bulan 1-13)

# %%
# 9. Visualisasi pergerakan nilai transaksi_tinggi bulan 1-12
plt.figure(figsize=(10, 5))
plt.plot(range(1, 13), transaksi_tinggi, marker='o', label='Transaksi Tertinggi 2011')
plt.title('Pergerakan Nilai Transaksi Tertinggi per Bulan (2011)')
plt.xlabel('Bulan')
plt.ylabel('Nilai Transaksi Tertinggi (Centroid Cluster)')
plt.xticks(range(1, 13))
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # 10. PredictedVal = prediksikan nilai transaksi tinggi dari transaksi_tinggi untuk bulan Januari 2012 dengan Linear Regression

# %%
# 10. Prediksi nilai transaksi tinggi untuk bulan Januari 2012 dengan Linear Regression
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
#Nilai bulan 1-12
X = np.array(range(1, 13)).reshape(-1, 1)
y = np.array(transaksi_tinggi)             

model = LinearRegression()
model.fit(X, y)
# nilai prediksi pada bulan januari 2012
bulan_prediksi = np.array([[13]])  
prediksi_jan_2012 = model.predict(bulan_prediksi)[0]
print(f"Prediksi nilai transaksi tinggi untuk Januari 2012: {prediksi_jan_2012:.2f}")

# Visualisasi nilai pada bulan 1-12 2011
plt.figure(figsize=(8, 5))
plt.plot(range(1, 13), model.predict(X), label='Prediksi Linear (2011)')
plt.scatter(range(1, 13), transaksi_tinggi, color='yellow', edgecolor='black', label='Data Aktual 2011', zorder=5)

# Visualisasi nilai pada bulan januari 2012
plt.scatter(13, prediksi_jan_2012, color='red', label='Prediksi Jan 2012', zorder=10)

plt.title('Prediksi Nilai Transaksi Tertinggi Bulan Januari 2012')
plt.xlabel('Bulan')
plt.ylabel('Nilai Transaksi Tertinggi')
plt.xticks(list(range(1, 14)))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Prediksi nilai transaksi tinggi untuk Januari 2012: 40.86

# %%
# 1. Load dataset dan tampilkan
dataset = pd.read_csv('transaction.csv')
print("Dataset:")
print(dataset.head())

# 2. Konversi InvoiceDate ke datetime dan ambil fitur yang diperlukan
dataset['InvoiceDate'] = pd.to_datetime(dataset['InvoiceDate'])
data = dataset[['InvoiceNo', 'Country', 'InvoiceDate']].copy()
data['month'] = data['InvoiceDate'].dt.month
data['year'] = data['InvoiceDate'].dt.year

# Filter hanya tahun 2011
data = data[data['year'] == 2011]
print("\nData setelah filter tahun 2011 dan ekstraksi fitur:")
print(data.head())

transaksi_tinggi = []

for i in range(1, 13):
    print(f"\n--- Bulan ke-{i} ---")
    
    # 3. Data bulan ke-i
    data_bulan = data[data['month'] == i]
    print(f"Data bulan ke-{i} (sample):")
    print(data_bulan.head(1))
    
    # 4. Hitung transaksi per negara (InvoiceNo unik per Country)
    
    transaksi = data_bulan.drop_duplicates(subset=['InvoiceNo', 'Country'])
    transaksi_per_country = transaksi.groupby('Country')['InvoiceNo'].nunique().reset_index()
    transaksi_per_country.columns = ['Country', 'TransactionCount']
    print("Transaksi per negara:")
    print(transaksi_per_country)
    
    # Jika data negara kurang dari 3, append 0 dan lanjut ke bulan berikutnya
    if len(transaksi_per_country) < 3:
        print(f"Data kurang dari 3 negara, lewati clustering bulan {i}.")
        transaksi_tinggi.append(0)
        continue
    
    # 5. Clustering dengan AgglomerativeClustering (Average Linkage, k=3)
    clustering = AgglomerativeClustering(n_clusters=3, linkage='average')
    clustering.fit(transaksi_per_country[['TransactionCount']])
    transaksi_per_country['Cluster'] = clustering.labels_
    print("Hasil clustering:")
    print(transaksi_per_country)
    
    # 6. Tentukan centroid (rata-rata transaksi tiap cluster)
    centroid = transaksi_per_country.groupby('Cluster')['TransactionCount'].mean().reset_index()
    print("Centroid per cluster:")
    print(centroid)
    
    # 7. Urutkan centroid ascending berdasarkan TransactionCount
    sorted_centroid = centroid.sort_values(by='TransactionCount').reset_index(drop=True)
    print("Centroid setelah diurutkan (ascending):")
    print(sorted_centroid)
    
    # 8. Ambil nilai tertinggi (indeks terakhir)
    nilai_tertinggi = sorted_centroid.loc[len(sorted_centroid) - 1, 'TransactionCount']
    transaksi_tinggi.append(nilai_tertinggi)
    print(f"Nilai transaksi tertinggi bulan {i}: {nilai_tertinggi}")

# 9. Visualisasi pergerakan nilai transaksi_tinggi bulan 1-12
plt.figure(figsize=(10, 5))
plt.plot(range(1, 13), transaksi_tinggi, marker='o', label='Transaksi Tertinggi 2011')
plt.title('Pergerakan Nilai Transaksi Tertinggi per Bulan (2011)')
plt.xlabel('Bulan')
plt.ylabel('Nilai Transaksi Tertinggi (Centroid Cluster)')
plt.xticks(range(1, 13))
plt.grid(True)
plt.legend()
plt.show()

# 10. Prediksi nilai transaksi tinggi untuk bulan Januari 2012 dengan Linear Regression
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

X = np.array(range(1, 13)).reshape(-1, 1)  # Bulan 1-12
y = np.array(transaksi_tinggi)             # Nilai transaksi tertinggi bulan 1-12

model = LinearRegression()
model.fit(X, y)

bulan_prediksi = np.array([[13]])  # Bulan Januari 2012
prediksi_jan_2012 = model.predict(bulan_prediksi)[0]
print(f"Prediksi nilai transaksi tinggi untuk Januari 2012: {prediksi_jan_2012:.2f}")

# Visualisasi hasil prediksi dan data aktual
plt.figure(figsize=(8, 5))

# Plot tren prediksi linear dari data 2011
plt.plot(range(1, 13), model.predict(X), label='Prediksi Linear (2011)')

# Titik data aktual bulan 1-12 (kuning dengan garis tepi hitam)
plt.scatter(range(1, 13), transaksi_tinggi, color='yellow', edgecolor='black', label='Data Aktual 2011', zorder=5)

# Titik prediksi bulan 13 (merah)
plt.scatter(13, prediksi_jan_2012, color='red', label='Prediksi Jan 2012', zorder=10)

plt.title('Prediksi Nilai Transaksi Tertinggi Bulan Januari 2012')
plt.xlabel('Bulan')
plt.ylabel('Nilai Transaksi Tertinggi')
plt.xticks(list(range(1, 14)))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Dataset:
#    InvoiceNo  StockCode  Qty      InvoiceDate  CustomerID  Country
# 0     537626      22725  830  12/7/2010 14:57       12347  Iceland
# 1     537626      22729  948  12/7/2010 14:57       12347  Iceland
# 2     537626      22195  695  12/7/2010 14:57       12347  Iceland
# 3     542237      22725  636  1/26/2011 14:30       12347  Iceland
# 4     542237      22729  536  1/26/2011 14:30       12347  Iceland
#
# Data setelah filter tahun 2011 dan ekstraksi fitur:
#    InvoiceNo  Country         InvoiceDate  month  year
# 3     542237  Iceland 2011-01-26 14:30:00      1  2011
# 4     542237  Iceland 2011-01-26 14:30:00      1  2011
# 5     542237  Iceland 2011-01-26 14:30:00      1  2011
# 6     542237  Iceland 2011-01-26 14:30:00      1  2011
# 7     542237  Iceland 2011-01-26 14:30:00      1  2011
#
# --- Bulan ke-1 ---
# Data bulan ke-1 (sample):
#    InvoiceNo  Country         InvoiceDate  month  year
# 3     542237  Iceland 2011-01-26 14:30:00      1  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0         Australia                 5
# 1           Belgium                 3
# 2   Channel Islands                 1
# 3            Cyprus                 1
# 4              EIRE                 7
# 5           Finland                 1
# 6            France                26
# 7           Germany                28
# 8            Greece                 1
# 9           Iceland                 1
# 10            Italy                 3
# 11          Lebanon                 1
# 12      Netherlands                 4
# 13           Poland                 1
# 14         Portugal                 4
# 15        Singapore                 1
# 16            Spain                 7
# 17           Sweden                 2
# 18      Switzerland                 3
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0         Australia                 5        0
# 1           Belgium                 3        0
# 2   Channel Islands                 1        0
# 3            Cyprus                 1        0
# 4              EIRE                 7        2
# 5           Finland                 1        0
# 6            France                26        1
# 7           Germany                28        1
# 8            Greece                 1        0
# 9           Iceland                 1        0
# 10            Italy                 3        0
# 11          Lebanon                 1        0
# 12      Netherlands                 4        0
# 13           Poland                 1        0
# 14         Portugal                 4        0
# 15        Singapore                 1        0
# 16            Spain                 7        2
# 17           Sweden                 2        0
# 18      Switzerland                 3        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          2.133333
# 1        1         27.000000
# 2        2          7.000000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0          2.133333
# 1        2          7.000000
# 2        1         27.000000
# Nilai transaksi tertinggi bulan 1: 27.0
#
# --- Bulan ke-2 ---
# Data bulan ke-2 (sample):
#     InvoiceNo Country         InvoiceDate  month  year
# 57     543037  Norway 2011-02-02 16:01:00      2  2011
# Transaksi per negara:
#                  Country  TransactionCount
# 0              Australia                 4
# 1                Austria                 1
# 2                Belgium                 4
# 3        Channel Islands                 1
# 4                 Cyprus                 4
# 5         Czech Republic                 1
# 6                Denmark                 1
# 7                   EIRE                 9
# 8                Finland                 1
# 9                 France                20
# 10               Germany                18
# 11                Israel                 1
# 12                 Italy                 1
# 13                 Japan                 2
# 14           Netherlands                 5
# 15                Norway                 2
# 16                Poland                 2
# 17              Portugal                 2
# 18          Saudi Arabia                 1
# 19                 Spain                 4
# 20                Sweden                 1
# 21           Switzerland                 4
# 22  United Arab Emirates                 1
# Hasil clustering:
#                  Country  TransactionCount  Cluster
# 0              Australia                 4        0
# 1                Austria                 1        0
# 2                Belgium                 4        0
# 3        Channel Islands                 1        0
# 4                 Cyprus                 4        0
# 5         Czech Republic                 1        0
# 6                Denmark                 1        0
# 7                   EIRE                 9        2
# 8                Finland                 1        0
# 9                 France                20        1
# 10               Germany                18        1
# 11                Israel                 1        0
# 12                 Italy                 1        0
# 13                 Japan                 2        0
# 14           Netherlands                 5        0
# 15                Norway                 2        0
# 16                Poland                 2        0
# 17              Portugal                 2        0
# 18          Saudi Arabia                 1        0
# 19                 Spain                 4        0
# 20                Sweden                 1        0
# 21           Switzerland                 4        0
# 22  United Arab Emirates                 1        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0              2.15
# 1        1             19.00
# 2        2              9.00
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0              2.15
# 1        2              9.00
# 2        1             19.00
# Nilai transaksi tertinggi bulan 2: 19.0
#
# --- Bulan ke-3 ---
# Data bulan ke-3 (sample):
#     InvoiceNo Country         InvoiceDate  month  year
# 61     546869  Norway 2011-03-17 16:00:00      3  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0         Australia                 3
# 1           Austria                 1
# 2           Belgium                 8
# 3   Channel Islands                 3
# 4            Cyprus                 1
# 5           Denmark                 1
# 6              EIRE                17
# 7           Finland                 3
# 8            France                23
# 9           Germany                26
# 10           Greece                 1
# 11            Italy                 3
# 12            Japan                 2
# 13      Netherlands                 8
# 14           Norway                 2
# 15           Poland                 1
# 16         Portugal                 4
# 17            Spain                 7
# 18           Sweden                 2
# 19      Switzerland                 2
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0         Australia                 3        0
# 1           Austria                 1        0
# 2           Belgium                 8        0
# 3   Channel Islands                 3        0
# 4            Cyprus                 1        0
# 5           Denmark                 1        0
# 6              EIRE                17        2
# 7           Finland                 3        0
# 8            France                23        1
# 9           Germany                26        1
# 10           Greece                 1        0
# 11            Italy                 3        0
# 12            Japan                 2        0
# 13      Netherlands                 8        0
# 14           Norway                 2        0
# 15           Poland                 1        0
# 16         Portugal                 4        0
# 17            Spain                 7        0
# 18           Sweden                 2        0
# 19      Switzerland                 2        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          3.058824
# 1        1         24.500000
# 2        2         17.000000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0          3.058824
# 1        2         17.000000
# 2        1         24.500000
# Nilai transaksi tertinggi bulan 3: 24.5
#
# --- Bulan ke-4 ---
# Data bulan ke-4 (sample):
#    InvoiceNo  Country         InvoiceDate  month  year
# 8     549222  Iceland 2011-04-07 10:43:00      4  2011
# Transaksi per negara:
#                Country  TransactionCount
# 0            Australia                 1
# 1              Austria                 1
# 2              Belgium                 7
# 3               Brazil                 1
# 4      Channel Islands                 1
# 5              Denmark                 1
# 6                 EIRE                11
# 7   European Community                 1
# 8              Finland                 3
# 9               France                11
# 10             Germany                21
# 11              Greece                 1
# 12             Iceland                 1
# 13               Italy                 2
# 14               Japan                 2
# 15         Netherlands                 3
# 16              Poland                 1
# 17            Portugal                 2
# 18           Singapore                 1
# 19               Spain                 2
# 20              Sweden                 1
# 21         Switzerland                 2
# 22                 USA                 1
# 23         Unspecified                 1
# Hasil clustering:
#                Country  TransactionCount  Cluster
# 0            Australia                 1        2
# 1              Austria                 1        2
# 2              Belgium                 7        0
# 3               Brazil                 1        2
# 4      Channel Islands                 1        2
# 5              Denmark                 1        2
# 6                 EIRE                11        0
# 7   European Community                 1        2
# 8              Finland                 3        2
# 9               France                11        0
# 10             Germany                21        1
# 11              Greece                 1        2
# 12             Iceland                 1        2
# 13               Italy                 2        2
# 14               Japan                 2        2
# 15         Netherlands                 3        2
# 16              Poland                 1        2
# 17            Portugal                 2        2
# 18           Singapore                 1        2
# 19               Spain                 2        2
# 20              Sweden                 1        2
# 21         Switzerland                 2        2
# 22                 USA                 1        2
# 23         Unspecified                 1        2
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          9.666667
# 1        1         21.000000
# 2        2          1.450000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        2          1.450000
# 1        0          9.666667
# 2        1         21.000000
# Nilai transaksi tertinggi bulan 4: 21.0
#
# --- Bulan ke-5 ---
# Data bulan ke-5 (sample):
#     InvoiceNo  Country         InvoiceDate  month  year
# 98     552449  Bahrain 2011-05-09 13:49:00      5  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0         Australia                 4
# 1           Austria                 1
# 2           Bahrain                 1
# 3           Belgium                 7
# 4   Channel Islands                 1
# 5           Denmark                 1
# 6              EIRE                16
# 7            France                34
# 8           Germany                33
# 9             Italy                 1
# 10            Japan                 1
# 11      Netherlands                 8
# 12           Poland                 3
# 13         Portugal                 1
# 14            Spain                 3
# 15           Sweden                 1
# 16      Switzerland                 3
# 17      Unspecified                 1
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0         Australia                 4        0
# 1           Austria                 1        0
# 2           Bahrain                 1        0
# 3           Belgium                 7        0
# 4   Channel Islands                 1        0
# 5           Denmark                 1        0
# 6              EIRE                16        2
# 7            France                34        1
# 8           Germany                33        1
# 9             Italy                 1        0
# 10            Japan                 1        0
# 11      Netherlands                 8        0
# 12           Poland                 3        0
# 13         Portugal                 1        0
# 14            Spain                 3        0
# 15           Sweden                 1        0
# 16      Switzerland                 3        0
# 17      Unspecified                 1        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          2.466667
# 1        1         33.500000
# 2        2         16.000000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0          2.466667
# 1        2         16.000000
# 2        1         33.500000
# Nilai transaksi tertinggi bulan 5: 33.5
#
# --- Bulan ke-6 ---
# Data bulan ke-6 (sample):
#     InvoiceNo  Country         InvoiceDate  month  year
# 14     556201  Iceland 2011-06-09 13:01:00      6  2011
# Transaksi per negara:
#                Country  TransactionCount
# 0            Australia                 4
# 1              Belgium                 9
# 2               Canada                 1
# 3      Channel Islands                 1
# 4               Cyprus                 2
# 5              Denmark                 3
# 6                 EIRE                20
# 7   European Community                 1
# 8              Finland                 1
# 9               France                28
# 10             Germany                20
# 11             Iceland                 1
# 12               Italy                 1
# 13               Japan                 1
# 14               Malta                 1
# 15         Netherlands                10
# 16              Norway                 3
# 17              Poland                 1
# 18            Portugal                 2
# 19               Spain                 7
# 20              Sweden                 3
# 21         Switzerland                 3
# 22         Unspecified                 1
# Hasil clustering:
#                Country  TransactionCount  Cluster
# 0            Australia                 4        0
# 1              Belgium                 9        0
# 2               Canada                 1        0
# 3      Channel Islands                 1        0
# 4               Cyprus                 2        0
# 5              Denmark                 3        0
# 6                 EIRE                20        1
# 7   European Community                 1        0
# 8              Finland                 1        0
# 9               France                28        2
# 10             Germany                20        1
# 11             Iceland                 1        0
# 12               Italy                 1        0
# 13               Japan                 1        0
# 14               Malta                 1        0
# 15         Netherlands                10        0
# 16              Norway                 3        0
# 17              Poland                 1        0
# 18            Portugal                 2        0
# 19               Spain                 7        0
# 20              Sweden                 3        0
# 21         Switzerland                 3        0
# 22         Unspecified                 1        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0               2.8
# 1        1              20.0
# 2        2              28.0
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0               2.8
# 1        1              20.0
# 2        2              28.0
# Nilai transaksi tertinggi bulan 6: 28.0
#
# --- Bulan ke-7 ---
# Data bulan ke-7 (sample):
#      InvoiceNo  Country         InvoiceDate  month  year
# 130     559707  Austria 2011-07-12 10:04:00      7  2011
# Transaksi per negara:
#                Country  TransactionCount
# 0            Australia                 5
# 1              Austria                 2
# 2              Belgium                 3
# 3               Canada                 1
# 4               Cyprus                 1
# 5              Denmark                 1
# 6                 EIRE                18
# 7   European Community                 1
# 8              Finland                 2
# 9               France                21
# 10             Germany                29
# 11              Greece                 1
# 12              Israel                 1
# 13               Italy                 1
# 14               Japan                 2
# 15         Netherlands                 1
# 16              Norway                 1
# 17              Poland                 2
# 18            Portugal                 3
# 19           Singapore                 1
# 20               Spain                 5
# 21              Sweden                 3
# 22         Switzerland                 5
# 23         Unspecified                 3
# Hasil clustering:
#                Country  TransactionCount  Cluster
# 0            Australia                 5        0
# 1              Austria                 2        0
# 2              Belgium                 3        0
# 3               Canada                 1        0
# 4               Cyprus                 1        0
# 5              Denmark                 1        0
# 6                 EIRE                18        1
# 7   European Community                 1        0
# 8              Finland                 2        0
# 9               France                21        1
# 10             Germany                29        2
# 11              Greece                 1        0
# 12              Israel                 1        0
# 13               Italy                 1        0
# 14               Japan                 2        0
# 15         Netherlands                 1        0
# 16              Norway                 1        0
# 17              Poland                 2        0
# 18            Portugal                 3        0
# 19           Singapore                 1        0
# 20               Spain                 5        0
# 21              Sweden                 3        0
# 22         Switzerland                 5        0
# 23         Unspecified                 3        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          2.142857
# 1        1         19.500000
# 2        2         29.000000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0          2.142857
# 1        1         19.500000
# 2        2         29.000000
# Nilai transaksi tertinggi bulan 7: 29.0
#
# --- Bulan ke-8 ---
# Data bulan ke-8 (sample):
#     InvoiceNo  Country         InvoiceDate  month  year
# 19     562032  Iceland 2011-08-02 08:48:00      8  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0         Australia                 2
# 1           Austria                 2
# 2           Belgium                 8
# 3            Canada                 1
# 4   Channel Islands                 5
# 5            Cyprus                 1
# 6           Denmark                 1
# 7              EIRE                15
# 8           Finland                 3
# 9            France                24
# 10          Germany                29
# 11          Iceland                 1
# 12           Israel                 1
# 13            Italy                 3
# 14            Malta                 1
# 15      Netherlands                 6
# 16           Norway                 2
# 17           Poland                 1
# 18         Portugal                 1
# 19            Spain                 7
# 20           Sweden                 4
# 21      Switzerland                 3
# 22      Unspecified                 2
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0         Australia                 2        1
# 1           Austria                 2        1
# 2           Belgium                 8        1
# 3            Canada                 1        1
# 4   Channel Islands                 5        1
# 5            Cyprus                 1        1
# 6           Denmark                 1        1
# 7              EIRE                15        2
# 8           Finland                 3        1
# 9            France                24        0
# 10          Germany                29        0
# 11          Iceland                 1        1
# 12           Israel                 1        1
# 13            Italy                 3        1
# 14            Malta                 1        1
# 15      Netherlands                 6        1
# 16           Norway                 2        1
# 17           Poland                 1        1
# 18         Portugal                 1        1
# 19            Spain                 7        1
# 20           Sweden                 4        1
# 21      Switzerland                 3        1
# 22      Unspecified                 2        1
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0             26.50
# 1        1              2.75
# 2        2             15.00
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        1              2.75
# 1        2             15.00
# 2        0             26.50
# Nilai transaksi tertinggi bulan 8: 26.5
#
# --- Bulan ke-9 ---
# Data bulan ke-9 (sample):
#     InvoiceNo  Country         InvoiceDate  month  year
# 43     568172  Finland 2011-09-25 13:13:00      9  2011
# Transaksi per negara:
#                  Country  TransactionCount
# 0              Australia                 6
# 1                Belgium                 6
# 2        Channel Islands                 2
# 3                 Cyprus                 1
# 4                Denmark                 3
# 5                   EIRE                28
# 6                Finland                 3
# 7                 France                43
# 8                Germany                33
# 9                  Italy                 1
# 10           Netherlands                 6
# 11                Norway                 6
# 12                Poland                 2
# 13              Portugal                 3
# 14                 Spain                 7
# 15                Sweden                 3
# 16           Switzerland                 4
# 17  United Arab Emirates                 1
# Hasil clustering:
#                  Country  TransactionCount  Cluster
# 0              Australia                 6        1
# 1                Belgium                 6        1
# 2        Channel Islands                 2        1
# 3                 Cyprus                 1        1
# 4                Denmark                 3        1
# 5                   EIRE                28        0
# 6                Finland                 3        1
# 7                 France                43        2
# 8                Germany                33        0
# 9                  Italy                 1        1
# 10           Netherlands                 6        1
# 11                Norway                 6        1
# 12                Poland                 2        1
# 13              Portugal                 3        1
# 14                 Spain                 7        1
# 15                Sweden                 3        1
# 16           Switzerland                 4        1
# 17  United Arab Emirates                 1        1
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0              30.5
# 1        1               3.6
# 2        2              43.0
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        1               3.6
# 1        0              30.5
# 2        2              43.0
# Nilai transaksi tertinggi bulan 9: 43.0
#
# --- Bulan ke-10 ---
# Data bulan ke-10 (sample):
#     InvoiceNo  Country         InvoiceDate  month  year
# 27     573511  Iceland 2011-10-31 12:25:00     10  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0         Australia                 4
# 1           Austria                 1
# 2           Belgium                11
# 3   Channel Islands                 3
# 4            Cyprus                 3
# 5    Czech Republic                 1
# 6           Denmark                 2
# 7              EIRE                27
# 8           Finland                 4
# 9            France                25
# 10          Germany                47
# 11          Iceland                 1
# 12           Israel                 1
# 13            Italy                 6
# 14            Japan                 1
# 15      Netherlands                 9
# 16           Norway                 4
# 17         Portugal                 6
# 18              RSA                 1
# 19        Singapore                 1
# 20            Spain                 7
# 21           Sweden                 2
# 22      Switzerland                 5
# 23              USA                 2
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0         Australia                 4        0
# 1           Austria                 1        0
# 2           Belgium                11        0
# 3   Channel Islands                 3        0
# 4            Cyprus                 3        0
# 5    Czech Republic                 1        0
# 6           Denmark                 2        0
# 7              EIRE                27        1
# 8           Finland                 4        0
# 9            France                25        1
# 10          Germany                47        2
# 11          Iceland                 1        0
# 12           Israel                 1        0
# 13            Italy                 6        0
# 14            Japan                 1        0
# 15      Netherlands                 9        0
# 16           Norway                 4        0
# 17         Portugal                 6        0
# 18              RSA                 1        0
# 19        Singapore                 1        0
# 20            Spain                 7        0
# 21           Sweden                 2        0
# 22      Switzerland                 5        0
# 23              USA                 2        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          3.571429
# 1        1         26.000000
# 2        2         47.000000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0          3.571429
# 1        1         26.000000
# 2        2         47.000000
# Nilai transaksi tertinggi bulan 10: 47.0
#
# --- Bulan ke-11 ---
# Data bulan ke-11 (sample):
#     InvoiceNo Country         InvoiceDate  month  year
# 44     577609   Italy 2011-11-21 09:51:00     11  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0         Australia                 3
# 1           Austria                 2
# 2           Belgium                 9
# 3   Channel Islands                 1
# 4            Cyprus                 1
# 5           Denmark                 2
# 6              EIRE                36
# 7           Finland                 3
# 8            France                58
# 9           Germany                52
# 10            Italy                 7
# 11            Japan                 1
# 12      Netherlands                11
# 13           Norway                 5
# 14           Poland                 2
# 15         Portugal                 6
# 16            Spain                10
# 17           Sweden                 3
# 18      Switzerland                 5
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0         Australia                 3        0
# 1           Austria                 2        0
# 2           Belgium                 9        0
# 3   Channel Islands                 1        0
# 4            Cyprus                 1        0
# 5           Denmark                 2        0
# 6              EIRE                36        2
# 7           Finland                 3        0
# 8            France                58        1
# 9           Germany                52        1
# 10            Italy                 7        0
# 11            Japan                 1        0
# 12      Netherlands                11        0
# 13           Norway                 5        0
# 14           Poland                 2        0
# 15         Portugal                 6        0
# 16            Spain                10        0
# 17           Sweden                 3        0
# 18      Switzerland                 5        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0            4.4375
# 1        1           55.0000
# 2        2           36.0000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0            4.4375
# 1        2           36.0000
# 2        1           55.0000
# Nilai transaksi tertinggi bulan 11: 55.0
#
# --- Bulan ke-12 ---
# Data bulan ke-12 (sample):
#      InvoiceNo  Country         InvoiceDate  month  year
# 131     581232  Austria 2011-12-08 10:26:00     12  2011
# Transaksi per negara:
#             Country  TransactionCount
# 0           Austria                 1
# 1           Belgium                 4
# 2   Channel Islands                 1
# 3           Denmark                 1
# 4              EIRE                 9
# 5           Finland                 1
# 6            France                15
# 7           Germany                16
# 8            Greece                 1
# 9             Italy                 1
# 10      Netherlands                 3
# 11           Norway                 1
# 12         Portugal                 4
# 13            Spain                 2
# 14              USA                 2
# Hasil clustering:
#             Country  TransactionCount  Cluster
# 0           Austria                 1        0
# 1           Belgium                 4        0
# 2   Channel Islands                 1        0
# 3           Denmark                 1        0
# 4              EIRE                 9        2
# 5           Finland                 1        0
# 6            France                15        1
# 7           Germany                16        1
# 8            Greece                 1        0
# 9             Italy                 1        0
# 10      Netherlands                 3        0
# 11           Norway                 1        0
# 12         Portugal                 4        0
# 13            Spain                 2        0
# 14              USA                 2        0
# Centroid per cluster:
#    Cluster  TransactionCount
# 0        0          1.833333
# 1        1         15.500000
# 2        2          9.000000
# Centroid setelah diurutkan (ascending):
#    Cluster  TransactionCount
# 0        0          1.833333
# 1        2          9.000000
# 2        1         15.500000
# Nilai transaksi tertinggi bulan 12: 15.5
# Prediksi nilai transaksi tinggi untuk Januari 2012: 40.86
